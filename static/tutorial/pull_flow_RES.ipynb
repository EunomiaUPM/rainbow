# %% [markdown]
# # Preconditions
# `./setup_auth.ipynb` and `./setup_catalog_policies.ipynb`will run

# %%
# %run ./setup_catalog_policies_oauth.ipynb
# Out:
# /Users/apabook/Desktop/ds-protocol/static/tutorial/venv/bin/python
# {
#     "participant_id": "did:jwk:...",
#     "participant_nick": "Myself",
#     "participant_type": "Agent",
#     "base_url": "http://127.0.0.1:1200",
#     "token": null,
#     "saved_at": "2026-09-02T14:25:08.215460Z",
#     "last_interaction": "2026-09-06T21:25:31.249689Z",
#     "extra_fields": {},
#     "is_me": true
# }
# {
#     "participant_id": "did:jwk:...",
#     "participant_nick": "Myself",
#     "participant_type": "Agent",
#     "base_url": "http://127.0.0.1:1100",
#     "token": null,
#     "saved_at": "2026-09-02T14:25:08.305843Z",
#     "last_interaction": "2026-09-06T21:25:31.471869Z",
#     "extra_fields": {},
#     "is_me": true
# }
# Provider DID: did:jwk:...
#
# Provider token: akuTZ784tLl7j96fX09XjK8ACYhdReuR4QHzfLClQP4
#
# Consumer DID: did:jwk:...
#
# Consumer token: akuTZ784tLl7j96fX09XjK8ACYhdReuR4QHzfLClQP4
# {
#     "dctConformsTo": null,
#     "dctCreator": null,
#     "dctIdentifier": "urn:catalog:6041b710-8595-45ff-88da-9bcb4a9e62a3",
#     "dctIssued": "2026-09-02T14:25:08.952727Z",
#     "dctModified": null,
#     "dctTitle": null,
#     "dspaceMainCatalog": true,
#     "dspaceParticipantId": "did:jwk:...",
#     "foafHomePage": null,
#     "id": "urn:catalog:6041b710-8595-45ff-88da-9bcb4a9e62a3"
# }
# {
#     "catalogId": "urn:catalog:6041b710-8595-45ff-88da-9bcb4a9e62a3",
#     "dcatEndpointDescription": null,
#     "dcatEndpointUrl": "http://127.0.0.1:1200/dsp/current",
#     "dctConformsTo": null,
#     "dctCreator": null,
#     "dctDescription": null,
#     "dctIdentifier": "urn:data-service:d7d3ab47-170c-456f-8c04-6f563e2c585c",
#     "dctIssued": "2026-09-02T14:25:09.001755Z",
#     "dctModified": null,
#     "dctTitle": null,
#     "dspaceMainDataService": true,
#     "id": "urn:data-service:d7d3ab47-170c-456f-8c04-6f563e2c585c"
# }
# {
#     "catalogId": "urn:catalog:6041b710-8595-45ff-88da-9bcb4a9e62a3",
#     "dctConformsTo": null,
#     "dctCreator": null,
#     "dctDescription": null,
#     "dctIdentifier": "urn:dataset:70c39823-f55a-4140-8505-25f72ae31b1a",
#     "dctIssued": "2026-09-06T21:39:06.931592Z",
#     "dctModified": null,
#     "dctTitle": "My dataspace dataset",
#     "id": "urn:dataset:70c39823-f55a-4140-8505-25f72ae31b1a"
# }
# {
#     "datasetId": "urn:dataset:70c39823-f55a-4140-8505-25f72ae31b1a",
#     "dcatAccessService": "urn:data-service:d7d3ab47-170c-456f-8c04-6f563e2c585c",
#     "dctDescription": "This is the distribution of my dataset",
#     "dctFormat": "http+asd",
#     "dctIssued": "2026-09-06T21:39:06.951852Z",
#     "dctModified": null,
#     "dctTitle": "Distribution of my dataset",
#     "id": "urn:distribution:ab11127c-4d2b-4d37-afb4-5754ff939084"
# }
# {
#     "datasetId": "urn:dataset:70c39823-f55a-4140-8505-25f72ae31b1a",
#     "dcatAccessService": "urn:data-service:d7d3ab47-170c-456f-8c04-6f563e2c585c",
#     "dctDescription": "This is the distribution of my streaming dataset",
#     "dctFormat": "http+pushing",
#     "dctIssued": "2026-09-06T21:39:06.972788Z",
#     "dctModified": null,
#     "dctTitle": "Distribution of a streaming dataset",
#     "id": "urn:distribution:ae1cd8b2-ef4e-481c-9410-2cfd8a0ac5d8"
# }
# [
#     {
#         "author": "",
#         "content": {
#             "permission": [
#                 {
#                     "action": "use",
#                     "constraint": [
#                         {
#                             "leftOperand": "bla",
#                             "operator": "eq",
#                             "rightOperand": "$bla"
#                         }
#                     ]
#                 }
#             ]
#         },
#         "date": "2026-09-02T14:25:09.008924Z",
#         "description": "Mi example super policy",
#         "id": "policy-1",
#         "parameters": {
#             "$bla": {
#                 "dataType": "string",
#                 "restrictions": {},
#                 "ui": {
#                     "hidden": false
#                 }
#             }
#         },
#         "title": "Mi example policy",
#         "version": "1.0"
#     }
# ]
# {
#     "createdAt": "2026-09-06T21:39:07.005979Z",
#     "description": "Research access for UPM: grants read access to did:web:university.upm.es valid until 2025-12-31.",
#     "entity": "urn:dataset:70c39823-f55a-4140-8505-25f72ae31b1a",
#     "entityType": "Dataset",
#     "id": "urn:odrl-policy:c4c1cacd-c7e9-43a6-b1b6-c8e2069c78a5",
#     "instantiationParameters": {
#         "$bla": "did:web:university.upm.es"
#     },
#     "odrlOffer": {
#         "permission": [
#             {
#                 "action": "use",
#                 "constraint": [
#                     {
#                         "leftOperand": "bla",
#                         "operator": "eq",
#                         "rightOperand": "did:web:university.upm.es"
#                     }
#                 ]
#             }
#         ]
#     },
#     "sourceTemplateId": "policy-1",
#     "sourceTemplateVersion": "1.0"
# }
# {
#     "createdAt": "2026-09-06T21:39:07.018902Z",
#     "description": "Commercial use licence valid for 2025: permits usage for commercial purposes with mandatory attribution. Derivation of the dataset is prohibited.",
#     "entity": "urn:dataset:70c39823-f55a-4140-8505-25f72ae31b1a",
#     "entityType": "Dataset",
#     "id": "urn:odrl-policy:198be589-4adf-4eb8-b16a-e074ea1f72ca",
#     "instantiationParameters": null,
#     "odrlOffer": {
#         "obligation": [
#             {
#                 "action": "attribute",
#                 "constraint": [
#                     {
#                         "leftOperand": "recipient",
#                         "operator": "isA",
#                         "rightOperand": "public"
#                     }
#                 ]
#             }
#         ],
#         "permission": [
#             {
#                 "action": "use",
#                 "constraint": [
#                     {
#                         "leftOperand": "dateTime",
#                         "operator": "gteq",
#                         "rightOperand": "2025-01-01T00:00:00Z"
#                     },
#                     {
#                         "leftOperand": "dateTime",
#                         "operator": "lteq",
#                         "rightOperand": "2025-12-31T23:59:59Z"
#                     },
#                     {
#                         "leftOperand": "purpose",
#                         "operator": "isA",
#                         "rightOperand": "commercial"
#                     }
#                 ]
#             }
#         ],
#         "prohibition": [
#             {
#                 "action": "derive",
#                 "constraint": []
#             }
#         ]
#     },
#     "sourceTemplateId": null,
#     "sourceTemplateVersion": null
# }
# {
#     "createdAt": "2026-09-06T21:39:07.030364Z",
#     "description": "Research trial access (Mar\u2013Sep 2025): read-only, limited to 10 000 requests, restricted to research purposes. Redistribution and reproduction are prohibited.",
#     "entity": "urn:dataset:70c39823-f55a-4140-8505-25f72ae31b1a",
#     "entityType": "Dataset",
#     "id": "urn:odrl-policy:c207258f-23f3-47be-a1c4-d453f146a6c8",
#     "instantiationParameters": null,
#     "odrlOffer": {
#         "obligation": [],
#         "permission": [
#             {
#                 "action": "read",
#                 "constraint": [
#                     {
#                         "leftOperand": "dateTime",
#                         "operator": "gteq",
#                         "rightOperand": "2025-03-01T00:00:00Z"
#                     },
#                     {
#                         "leftOperand": "dateTime",
#                         "operator": "lteq",
#                         "rightOperand": "2025-09-01T00:00:00Z"
#                     },
#                     {
#                         "leftOperand": "purpose",
#                         "operator": "isA",
#                         "rightOperand": "research"
#                     },
#                     {
#                         "leftOperand": "count",
#                         "operator": "lteq",
#                         "rightOperand": "10000"
#                     }
#                 ]
#             }
#         ],
#         "prohibition": [
#             {
#                 "action": "distribute",
#                 "constraint": []
#             },
#             {
#                 "action": "reproduce",
#                 "constraint": []
#             }
#         ]
#     },
#     "sourceTemplateId": null,
#     "sourceTemplateVersion": null
# }
# {
#     "message": "Database Error",
#     "error_code": 5100,
#     "details": "Secret already exists"
# }
# {
#     "name": "urn:connector-template:84625ea1-9d9e-46ca-9d91-2efbb63d9ec2",
#     "author": "admin",
#     "description": null,
#     "version": "1.0",
#     "createdAt": "2026-09-06T21:39:07.105947Z",
#     "authentication": {
#         "type": "BEARER_TOKEN",
#         "token": {
#             "type": "PLAIN",
#             "content": "{{__RUNTIME_SECRET_{/ecostars/api_key}__}}"
#         }
#     },
#     "interaction": {
#         "mode": "PULL",
#         "dataAccess": {
#             "protocol": "HTTP",
#             "urlTemplate": "{{__ACCESS_URL__}}",
#             "method": "{{__ACCESS_METHODS__}}",
#             "headers": "{{__ACCESS_HEADERS__}}",
#             "bodyTemplate": null
#         }
#     },
#     "parameters": [
#         {
#             "name": "ACCESS_URL",
#             "title": "Url",
#             "description": null,
#             "paramType": "STRING",
#             "required": true,
#             "defaultValue": null
#         },
#         {
#             "name": "ACCESS_METHODS",
#             "title": "Methods",
#             "description": null,
#             "paramType": "VEC<STRING>",
#             "required": true,
#             "defaultValue": null
#         },
#         {
#             "name": "ACCESS_HEADERS",
#             "title": "Headers",
#             "description": null,
#             "paramType": "MAP<STRING,STRING>",
#             "required": true,
#             "defaultValue": null
#         }
#     ]
# }
# {
#     "id": "urn:connector-instance:2651fc69-f970-4720-afc7-9ee48cf3be5c",
#     "name": "urn:connector-template:84625ea1-9d9e-46ca-9d91-2efbb63d9ec2",
#     "author": null,
#     "description": null,
#     "version": "1.0",
#     "createdAt": "2026-09-06T21:39:07.124088Z",
#     "authenticationConfig": {
#         "type": "BEARER_TOKEN",
#         "token": {
#             "type": "PLAIN",
#             "content": "{{__RUNTIME_SECRET_{/ecostars/api_key}__}}"
#         }
#     },
#     "interaction": {
#         "mode": "PULL",
#         "dataAccess": {
#             "protocol": "HTTP",
#             "urlTemplate": "http://127.0.0.1:8081",
#             "method": [
#                 "GET",
#                 "HEAD"
#             ],
#             "headers": {
#                 "Content-type": "application/json"
#             },
#             "bodyTemplate": null
#         }
#     },
#     "distributionId": "urn:distribution:ab11127c-4d2b-4d37-afb4-5754ff939084"
# }
# {
#     "name": "urn:connector-template:affca0aa-ddd5-49a3-9566-cf2e62d48d3a",
#     "author": "admin",
#     "description": null,
#     "version": "1.0",
#     "createdAt": "2026-09-06T21:39:07.208234Z",
#     "authentication": {
#         "type": "BEARER_TOKEN",
#         "token": {
#             "type": "PLAIN",
#             "content": "{{__RUNTIME_SECRET_{/ecostars/api_key}__}}"
#         }
#     },
#     "interaction": {
#         "mode": "PUSH",
#         "subscribe": {
#             "protocol": "HTTP",
#             "urlTemplate": "{{__SUB_URL__}}",
#             "method": "POST",
#             "headers": {},
#             "bodyTemplate": "{\"url\": \"{{__SYS_OWN_URL_DOCKER__}}{{__RUNTIME_INGRESS__}}\", \"event_type\": \"hotel_waste_generated\"}"
#         },
#         "unsubscribe": {
#             "protocol": "HTTP",
#             "urlTemplate": "{{__UNSUB_URL__}}/{{__RUNTIME_JSON_{.subscription.data.ID}__}}",
#             "method": "POST",
#             "headers": {},
#             "bodyTemplate": "{}"
#         }
#     },
#     "parameters": [
#         {
#             "name": "SUB_URL",
#             "title": "Subscription URL",
#             "description": null,
#             "paramType": "STRING",
#             "required": true,
#             "defaultValue": null
#         },
#         {
#             "name": "UNSUB_URL",
#             "title": "Unsubscription URL",
#             "description": null,
#             "paramType": "STRING",
#             "required": true,
#             "defaultValue": null
#         }
#     ]
# }
# {
#     "id": "urn:connector-instance:6b9ea5d4-11ad-4929-aafc-7c4426399739",
#     "name": "urn:connector-template:affca0aa-ddd5-49a3-9566-cf2e62d48d3a",
#     "author": null,
#     "description": null,
#     "version": "1.0",
#     "createdAt": "2026-09-06T21:39:07.222542Z",
#     "authenticationConfig": {
#         "type": "BEARER_TOKEN",
#         "token": {
#             "type": "PLAIN",
#             "content": "{{__RUNTIME_SECRET_{/ecostars/api_key}__}}"
#         }
#     },
#     "interaction": {
#         "mode": "PUSH",
#         "subscribe": {
#             "protocol": "HTTP",
#             "urlTemplate": "http://127.0.0.1:8082/subscriptions/subscribe",
#             "method": "POST",
#             "headers": {},
#             "bodyTemplate": "{\"url\": \"http://host.docker.internal:1200{{__RUNTIME_INGRESS__}}\", \"event_type\": \"hotel_waste_generated\"}"
#         },
#         "unsubscribe": {
#             "protocol": "HTTP",
#             "urlTemplate": "http://127.0.0.1:8082/subscriptions/unsubscribe/{{__RUNTIME_JSON_{.subscription.data.ID}__}}",
#             "method": "POST",
#             "headers": {},
#             "bodyTemplate": "{}"
#         }
#     },
#     "distributionId": "urn:distribution:ae1cd8b2-ef4e-481c-9410-2cfd8a0ac5d8"
# }
# Selected dataset target:
# urn:dataset:70c39823-f55a-4140-8505-25f72ae31b1a
#
# Selected policy id:
# urn:odrl-policy:c38332f6-4af1-4d5b-99ef-df9a33a651a3
#
# Provider negotiation URL for DSP 2025:
# http://127.0.0.1:1200/dsp/current
#
# Consumer callback address:
# http://127.0.0.1:1100/dsp/current

# %% [markdown]
# # Contract Negotiation

# %% [markdown]
# ## Initialization of negotiation request (Consumer -> Provider)

# %%
url = data_space_consumer + "/dsp/current/negotiations/rpc/setup-request-init"
payload = {
    "associatedAgentPeer": data_space_provider_participant_id,
    "providerAddress": data_space_provider_dsp_endpoint,
    "callbackAddress": data_space_consumer_dsp_endpoint,
    "offer": {
        "@id": policy_id,
        "target": target_id,
        "@type": "Offer",
        "permission": [
            {
                "action": "use", 
                "constraint": [{
                    "leftOperand": "count", 
                    "operator": "gt", 
                    "rightOperand": "18"
                }]
            }
        ]
    }
}




try:
    response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
    response_as_json = response.json()
    cn_consumer_id = response_as_json["response"]["consumerPid"]
    cn_provider_id = response_as_json["response"]["providerPid"]
    print(json.dumps(response_as_json, indent=2))
except Exception as e:
    print("Error in response, {}.".format(e))
# Out:
# {
#   "request": {
#     "associatedAgentPeer": "did:jwk:...",
#     "providerAddress": "http://127.0.0.1:1200/dsp/current",
#     "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#     "offer": {
#       "@id": "urn:odrl-policy:f4e35fa8-ed4f-4163-a101-78a01823ea38",
#       "permission": [
#         {
#           "action": "use",
#           "constraint": [
#             {
#               "rightOperand": "18",
#               "leftOperand": "count",
#               "operator": "gt"
#             }
#           ]
#         }
#       ],
#       "@type": "Offer",
#       "target": "urn:dataset:caa14747-9566-4f70-8bd5-ed0af0fa5d08"
#     }
#   },
#   "response": {
#     "@context": [
#       "https://w3id.org/dspace/2025/1/context.jsonld"
#     ],
#     "@type": "ContractNegotiation",
#     "consumerPid": "urn:consumer-pid:5c675890-c25b-4911-b828-e549a3ea3026",
#     "providerPid": "urn:provider-pid:b25be9b9-bb19-47de-ac2d-f2f3d6d1d122",
#     "state": "REQUESTED"
#   },
#   "negotiationAgentModel": {
#     "id": "urn:negotiation-process:0f0c1364-919a-48e2-9f74-2590539a670b",
#     "state": "REQUESTED",
#     "stateAttribute": null,
#     "associatedAgentPeer": "did:jwk:...",
#     "protocol": "DSP",
#     "callbackAddress": "http://127.0.0.1:1200/dsp/current",
#     "role": "Consumer",
#     "properties": {},
#     "errorDetails": null,
#     "createdAt": "2026-09-04T14:11:47.702358Z",
#     "updatedAt": null,
#     "identifiers": {
#       "consumerPid": "urn:consumer-pid:5c675890-c25b-4911-b828-e549a3ea3026",
#       "providerPid": "urn:provider-pid:b25be9b9-bb19-47de-ac2d-f2f3d6d1d122"
#     },
#     "messages": [
#       {
#         "id": "urn:negotiation-message:cfc9de4b-db55-4109-84bc-f86738f2babc",
#         "negotiationAgentProcessId": "urn:negotiation-process:0f0c1364-919a-48e2-9f74-2590539a670b",
#         "createdAt": "2026-09-04T14:11:47.811217Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "-",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "associatedAgentPeer": "did:jwk:...",
#           "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#           "offer": {
#             "@id": "urn:odrl-policy:f4e35fa8-ed4f-4163-a101-78a01823ea38",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "18"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:caa14747-9566-4f70-8bd5-ed0af0fa5d08"
#           },
#           "providerAddress": "http://127.0.0.1:1200/dsp/current"
#         }
#       }
#     ],
#     "offers": [
#       {
#         "id": "urn:offer:9dcf2326-41db-4608-8a44-243377e52dbd",
#         "negotiationAgentProcessId": "urn:negotiation-process:0f0c1364-919a-48e2-9f74-2590539a670b",
#         "negotiationAgentMessageId": "urn:negotiation-message:cfc9de4b-db55-4109-84bc-f86738f2babc",
#         "offerId": "urn:odrl-policy:f4e35fa8-ed4f-4163-a101-78a01823ea38",
#         "offerContent": {
#           "@id": "urn:odrl-policy:f4e35fa8-ed4f-4163-a101-78a01823ea38",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "18"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:caa14747-9566-4f70-8bd5-ed0af0fa5d08"
#         },
#         "createdAt": "2026-09-04T14:11:47.813979Z"
#       }
#     ],
#     "agreement": null
#   }
# }

# %% [markdown]
# ## Provider creates initial offer (Provider -> Consumer)

# %%
# Provider creates initial offer (Provider -> Consumer)
url = data_space_provider + "/dsp/current/negotiations/rpc/setup-offer"
payload = {
    "consumerPid": cn_consumer_id,  # remove to test offer from provider
    "providerPid": cn_provider_id,  # remove to test offer from provider
    "offer": {
        "@id": policy_id,
        "target": target_id,
        "@type": "Offer",
        "permission": [
            {
                "action": "use", 
                "constraint": [{
                    "leftOperand": "count", 
                    "operator": "gt", 
                    "rightOperand": "21"
                }]
            }
        ]
    }
}
response = requests.request("POST", url, headers=json_header, data=json.dumps(payload))
response_as_json = response.json()
try:
    print(json.dumps(response_as_json, indent=2))
except KeyError:
    print("Error in response, check the payload and the endpoint.")
    print(json.dumps(response_as_json, indent=2))
    raise
# Out:
# {
#   "request": {
#     "offer": {
#       "@id": "urn:odrl-policy:f4e35fa8-ed4f-4163-a101-78a01823ea38",
#       "permission": [
#         {
#           "action": "use",
#           "constraint": [
#             {
#               "rightOperand": "21",
#               "leftOperand": "count",
#               "operator": "gt"
#             }
#           ]
#         }
#       ],
#       "@type": "Offer",
#       "target": "urn:dataset:caa14747-9566-4f70-8bd5-ed0af0fa5d08"
#     },
#     "providerPid": "urn:provider-pid:b25be9b9-bb19-47de-ac2d-f2f3d6d1d122",
#     "consumerPid": "urn:consumer-pid:5c675890-c25b-4911-b828-e549a3ea3026"
#   },
#   "response": {
#     "@context": [
#       "https://w3id.org/dspace/2025/1/context.jsonld"
#     ],
#     "@type": "ContractNegotiation",
#     "consumerPid": "urn:consumer-pid:5c675890-c25b-4911-b828-e549a3ea3026",
#     "providerPid": "urn:provider-pid:b25be9b9-bb19-47de-ac2d-f2f3d6d1d122",
#     "state": "OFFERED"
#   },
#   "negotiationAgentModel": {
#     "id": "urn:negotiation-process:54b38314-c56c-47f3-a62b-9088ee826cc4",
#     "state": "OFFERED",
#     "stateAttribute": null,
#     "associatedAgentPeer": "did:jwk:...",
#     "protocol": "DSP",
#     "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#     "role": "Provider",
#     "properties": {},
#     "errorDetails": null,
#     "createdAt": "2026-09-04T14:11:47.613023Z",
#     "updatedAt": "2026-09-04T14:11:47.889383Z",
#     "identifiers": {
#       "providerPid": "urn:provider-pid:b25be9b9-bb19-47de-ac2d-f2f3d6d1d122",
#       "consumerPid": "urn:consumer-pid:5c675890-c25b-4911-b828-e549a3ea3026"
#     },
#     "messages": [
#       {
#         "id": "urn:negotiation-message:ae3931a2-bc29-407e-8407-19303b9e6a49",
#         "negotiationAgentProcessId": "urn:negotiation-process:54b38314-c56c-47f3-a62b-9088ee826cc4",
#         "createdAt": "2026-09-04T14:11:47.696553Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "-",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#           "consumerPid": "urn:consumer-pid:5c675890-c25b-4911-b828-e549a3ea3026",
#           "offer": {
#             "@id": "urn:odrl-policy:f4e35fa8-ed4f-4163-a101-78a01823ea38",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "18"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:caa14747-9566-4f70-8bd5-ed0af0fa5d08"
#           }
#         }
#       },
#       {
#         "id": "urn:negotiation-message:9063b561-a7c7-4b20-9166-0ac1fce49984",
#         "negotiationAgentProcessId": "urn:negotiation-process:54b38314-c56c-47f3-a62b-9088ee826cc4",
#         "createdAt": "2026-09-04T14:11:47.895667Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:5c675890-c25b-4911-b828-e549a3ea3026",
#           "offer": {
#             "@id": "urn:odrl-policy:f4e35fa8-ed4f-4163-a101-78a01823ea38",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "21"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:caa14747-9566-4f70-8bd5-ed0af0fa5d08"
#           },
#           "providerPid": "urn:provider-pid:b25be9b9-bb19-47de-ac2d-f2f3d6d1d122"
#         }
#       }
#     ],
#     "offers": [
#       {
#         "id": "urn:offer:e1ebff88-b8e1-4d9e-9e62-dce3fe061929",
#         "negotiationAgentProcessId": "urn:negotiation-process:54b38314-c56c-47f3-a62b-9088ee826cc4",
#         "negotiationAgentMessageId": "urn:negotiation-message:ae3931a2-bc29-407e-8407-19303b9e6a49",
#         "offerId": "urn:odrl-policy:f4e35fa8-ed4f-4163-a101-78a01823ea38",
#         "offerContent": {
#           "@id": "urn:odrl-policy:f4e35fa8-ed4f-4163-a101-78a01823ea38",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "18"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:caa14747-9566-4f70-8bd5-ed0af0fa5d08"
#         },
#         "createdAt": "2026-09-04T14:11:47
z",
#     "identifiers": {
#       "consumerPid": "urn:consumer-pid:5c675890-c25b-4911-b828-e549a3ea3026",
#       "providerPid": "urn:provider-pid:b25be9b9-bb19-47de-ac2d-f2f3d6d1d122"
#     },
#     "messages": [
#       {
#         "id": "urn:negotiation-message:ae3931a2-bc29-407e-8407-19303b9e6a49",
#         "negotiationAgentProcessId": "urn:negotiation-process:54b38314-c56c-47f3-a62b-9088ee826cc4",
#         "createdAt": "2026-09-04T14:11:47.696553Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "-",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "callbackAddress": "http://127.0.0.1:1100/dsp/current",
#           "consumerPid": "urn:consumer-pid:5c675890-c25b-4911-b828-e549a3ea3026",
#           "offer": {
#             "@id": "urn:odrl-policy:f4e35fa8-ed4f-4163-a101-78a01823ea38",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "18"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:caa14747-9566-4f70-8bd5-ed0af0fa5d08"
#           }
#         }
#       },
#       {
#         "id": "urn:negotiation-message:9063b561-a7c7-4b20-9166-0ac1fce49984",
#         "negotiationAgentProcessId": "urn:negotiation-process:54b38314-c56c-47f3-a62b-9088ee826cc4",
#         "createdAt": "2026-09-04T14:11:47.895667Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:5c675890-c25b-4911-b828-e549a3ea3026",
#           "offer": {
#             "@id": "urn:odrl-policy:f4e35fa8-ed4f-4163-a101-78a01823ea38",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use",
#                 "constraint": [
#                   {
#                     "leftOperand": "count",
#                     "operator": "gt",
#                     "rightOperand": "21"
#                   }
#                 ]
#               }
#             ],
#             "target": "urn:dataset:caa14747-9566-4f70-8bd5-ed0af0fa5d08"
#           },
#           "providerPid": "urn:provider-pid:b25be9b9-bb19-47de-ac2d-f2f3d6d1d122"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:fc469706-1cc8-4226-98cf-d638d61c7b16",
#         "negotiationAgentProcessId": "urn:negotiation-process:54b38314-c56c-47f3-a62b-9088ee826cc4",
#         "createdAt": "2026-09-04T14:11:47.949374Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractRequestMessage",
#         "stateTransitionFrom": "OFFERED",
#         "stateTransitionTo": "REQUESTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractRequestMessage",
#           "consumerPid": "urn:consumer-pid:5c675890-c25b-4911-b828-e549a3ea3026",
#           "offer": {
#             "@id": "urn:odrl-policy:f4e35fa8-ed4f-4163-a101-78a01823ea38",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "use"
#               }
#             ],
#             "target": "urn:dataset:caa14747-9566-4f70-8bd5-ed0af0fa5d08"
#           },
#           "providerPid": "urn:provider-pid:b25be9b9-bb19-47de-ac2d-f2f3d6d1d122"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:1290e0ca-0c09-48dc-8463-dcc43748cbe6",
#         "negotiationAgentProcessId": "urn:negotiation-process:54b38314-c56c-47f3-a62b-9088ee826cc4",
#         "createdAt": "2026-09-04T14:11:48.167354Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractOfferMessage",
#         "stateTransitionFrom": "REQUESTED",
#         "stateTransitionTo": "OFFERED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractOfferMessage",
#           "consumerPid": "urn:consumer-pid:5c675890-c25b-4911-b828-e549a3ea3026",
#           "offer": {
#             "@id": "urn:odrl-policy:f4e35fa8-ed4f-4163-a101-78a01823ea38",
#             "@type": "Offer",
#             "permission": [
#               {
#                 "action": "supermegause"
#               }
#             ],
#             "target": "urn:dataset:caa14747-9566-4f70-8bd5-ed0af0fa5d08"
#           },
#           "providerPid": "urn:provider-pid:b25be9b9-bb19-47de-ac2d-f2f3d6d1d122"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:7f083709-ab1e-4581-a122-545861219b27",
#         "negotiationAgentProcessId": "urn:negotiation-process:54b38314-c56c-47f3-a62b-9088ee826cc4",
#         "createdAt": "2026-09-04T14:11:48.292319Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractNegotiationEventMessage",
#         "stateTransitionFrom": "OFFERED",
#         "stateTransitionTo": "ACCEPTED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractNegotiationEventMessage",
#           "consumerPid": "urn:consumer-pid:5c675890-c25b-4911-b828-e549a3ea3026",
#           "eventType": "ACCEPTED",
#           "providerPid": "urn:provider-pid:b25be9b9-bb19-47de-ac2d-f2f3d6d1d122"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:891e66a5-b517-45b3-84f6-7d5c3125fd0e",
#         "negotiationAgentProcessId": "urn:negotiation-process:54b38314-c56c-47f3-a62b-9088ee826cc4",
#         "createdAt": "2026-09-04T14:11:48.507761Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractAgreementMessage",
#         "stateTransitionFrom": "ACCEPTED",
#         "stateTransitionTo": "AGREED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractAgreementMessage",
#           "consumerPid": "urn:consumer-pid:5c675890-c25b-4911-b828-e549a3ea3026",
#           "providerPid": "urn:provider-pid:b25be9b9-bb19-47de-ac2d-f2f3d6d1d122"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:78c919eb-afdf-4114-a99b-90b599ae469c",
#         "negotiationAgentProcessId": "urn:negotiation-process:54b38314-c56c-47f3-a62b-9088ee826cc4",
#         "createdAt": "2026-09-04T14:11:49.381322Z",
#         "direction": "INBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractAgreementVerificationMessage",
#         "stateTransitionFrom": "AGREED",
#         "stateTransitionTo": "VERIFIED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractAgreementVerificationMessage",
#           "consumerPid": "urn:consumer-pid:5c675890-c25b-4911-b828-e549a3ea3026",
#           "providerPid": "urn:provider-pid:b25be9b9-bb19-47de-ac2d-f2f3d6d1d122"
#         }
#       },
#       {
#         "id": "urn:negotiation-message:7001e354-821c-42f3-9002-d3bcb95f723e",
#         "negotiationAgentProcessId": "urn:negotiation-process:54b38314-c56c-47f3-a62b-9088ee826cc4",
#         "createdAt": "2026-09-04T14:11:49.793189Z",
#         "direction": "OUTBOUND",
#         "protocol": "DSP",
#         "messageType": "ContractNegotiationEventMessage",
#         "stateTransitionFrom": "VERIFIED",
#         "stateTransitionTo": "FINALIZED",
#         "payload": {
#           "@context": [
#             "https://w3id.org/dspace/2025/1/context.jsonld"
#           ],
#           "@type": "ContractNegotiationEventMessage",
#           "consumerPid": "urn:consumer-pid:5c675890-c25b-4911-b828-e549a3ea3026",
#           "providerPid": "urn:provider-pid:b25be9b9-bb19-47de-ac2d-f2f3d6d1d122"
#         }
#       }
#     ],
#     "offers": [
#       {
#         "id": "urn:offer:e1ebff88-b8e1-4d9e-9e62-dce3fe061929",
#         "negotiationAgentProcessId": "urn:negotiation-process:54b38314-c56c-47f3-a62b-9088ee826cc4",
#         "negotiationAgentMessageId": "urn:negotiation-message:ae3931a2-bc29-407e-8407-19303b9e6a49",
#         "offerId": "urn:odrl-policy:f4e35fa8-ed4f-4163-a101-78a01823ea38",
#         "offerContent": {
#           "@id": "urn:odrl-policy:f4e35fa8-ed4f-4163-a101-78a01823ea38",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "18"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:caa14747-9566-4f70-8bd5-ed0af0fa5d08"
#         },
#         "createdAt": "2026-09-04T14:11:47.698661Z"
#       },
#       {
#         "id": "urn:offer:ca98e495-3159-470c-bea8-e36dcc8340ed",
#         "negotiationAgentProcessId": "urn:negotiation-process:54b38314-c56c-47f3-a62b-9088ee826cc4",
#         "negotiationAgentMessageId": "urn:negotiation-message:9063b561-a7c7-4b20-9166-0ac1fce49984",
#         "offerId": "urn:odrl-policy:f4e35fa8-ed4f-4163-a101-78a01823ea38",
#         "offerContent": {
#           "@id": "urn:odrl-policy:f4e35fa8-ed4f-4163-a101-78a01823ea38",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use",
#               "constraint": [
#                 {
#                   "leftOperand": "count",
#                   "operator": "gt",
#                   "rightOperand": "21"
#                 }
#               ]
#             }
#           ],
#           "target": "urn:dataset:caa14747-9566-4f70-8bd5-ed0af0fa5d08"
#         },
#         "createdAt": "2026-09-04T14:11:47.897599Z"
#       },
#       {
#         "id": "urn:offer:935d9660-fc9b-4b30-8f27-b6b49ac47fec",
#         "negotiationAgentProcessId": "urn:negotiation-process:54b38314-c56c-47f3-a62b-9088ee826cc4",
#         "negotiationAgentMessageId": "urn:negotiation-message:fc469706-1cc8-4226-98cf-d638d61c7b16",
#         "offerId": "urn:odrl-policy:f4e35fa8-ed4f-4163-a101-78a01823ea38",
#         "offerContent": {
#           "@id": "urn:odrl-policy:f4e35fa8-ed4f-4163-a101-78a01823ea38",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "use"
#             }
#           ],
#           "target": "urn:dataset:caa14747-9566-4f70-8bd5-ed0af0fa5d08"
#         },
#         "createdAt": "2026-09-04T14:11:47.950701Z"
#       },
#       {
#         "id": "urn:offer:0c85e01c-a98f-4d2f-834e-ed12db7a5d96",
#         "negotiationAgentProcessId": "urn:negotiation-process:54b38314-c56c-47f3-a62b-9088ee826cc4",
#         "negotiationAgentMessageId": "urn:negotiation-message:1290e0ca-0c09-48dc-8463-dcc43748cbe6",
#         "offerId": "urn:odrl-policy:f4e35fa8-ed4f-4163-a101-78a01823ea38",
#         "offerContent": {
#           "@id": "urn:odrl-policy:f4e35fa8-ed4f-4163-a101-78a01823ea38",
#           "@type": "Offer",
#           "permission": [
#             {
#               "action": "supermegause"
#             }
#           ],
#           "target": "urn:dataset:caa14747-9566-4f70-8bd5-ed0af0fa5d08"
#         },
#         "createdAt": "2026-09-04T14:11:48.169314Z"
#       }
#     ],
#     "agreement": {
#       "id": "urn:agreement:a905d0aa-cca3-42cc-881e-6a81bb7d3833",
#       "negotiationAgentProcessId": "urn:negotiation-process:54b38314-c56c-47f3-a62b-9088ee826cc4",
#       "negotiationAgentMessageId": "urn:negotiation-message:891e66a5-b517-45b3-84f6-7d5c3125fd0e",
#       "consumerParticipantId": "did:jwk:...",
#       "providerParticipantId": "did:jwk:...",
#       "agreementContent": {
#         "@id": "urn:agreement:a905d0aa-cca3-42cc-881e-6a81bb7d3833",
#         "@type": "Agreement",
#         "assignee": "did:jwk:...",
#         "assigner": "did:jwk:...",
#         "permission": [
#           {
#             "action": "supermegause"
#           }
#         ],
#         "target": "urn:dataset:caa14747-9566-4f70-8bd5-ed0af0fa5d08",
#         "timestamp": "1788531108"
#       },
#       "target": "urn:dataset:caa14747-9566-4f70-8bd5-ed0af0fa5d08",
#       "state": "ACTIVE",
#       "createdAt": "2026-09-04T14:11:48.509998Z",
#       "updatedAt": "2026-09-04T14:11:49.800659Z"
#     }
#   }
# }

# %% [markdown]
# ## Final agreement

# %%
print("Final agreement: \n{}\n".format(json.dumps(agreement["negotiationAgentModel"]["agreement"], indent=2)))
print("Final agreement id: \n{}\n".format(agreement_id))
# Out:
# Final agreement:
# {
#   "id": "urn:agreement:a905d0aa-cca3-42cc-881e-6a81bb7d3833",
#   "negotiationAgentProcessId": "urn:negotiation-process:54b38314-c56c-47f3-a62b-9088ee826cc4",
#   "negotiationAgentMessageId": "urn:negotiation-message:891e66a5-b517-45b3-84f6-7d5c3125fd0e",
#   "consumerParticipantId": "did:jwk:...",
#   "providerParticipantId": "did:jwk:...",
#   "agreementContent": {
#     "@id": "urn:agreement:a905d0aa-cca3-42cc-881e-6a81bb7d3833",
#     "@type": "Agreement",
#     "assignee": "did:jwk:...",
#     "assigner": "did:jwk:...",
#     "permission": [
#       {
#         "action": "supermegause"
#       }
#     ],
#     "target": "urn:dataset:caa14747-9566-4f70-8bd5-ed0af0fa5d08",
#     "timestamp": "1788531108"
#   },
#   "target": "urn:dataset:caa14747-9566-4f70-8bd5-ed0af0fa5d08",
#   "state": "ACTIVE",
#   "createdAt": "2026-09-04T14:11:48.509998Z",
#   "updatedAt": "2026-09-04T14:11:49.800659Z"
# }
#
# Final agreement id:
# urn:agreement:a905d0aa-cca3-42cc-881e-6a81bb7d3833

# %% [markdown]
# # Transfer Negotiation with Agents

# %% [markdown]
# ## Transfer request setup (Consumer -> Provider)

# %%
url = data_space_provider + "/dsp/current/transfers/request"
payload = {
  "@context": [
    "https://w3id.org/dspace/2025/1/context.jsonld"
  ],
  "@type": "TransferRequestMessage",
  "consumerPid": "urn:uuid:32541fe6-c580-409e-85a8-8a9a32fbe833",
  "agreementId": "urn:uuid:e8dc8655-44c2-46ef-b701-4cffdc2faa44",
  "format": "example:HTTP_PUSH",
  "dataAddress": {
    "@type": "DataAddress",
    "endpointType": "https://w3id.org/idsa/v4.1/HTTP",
    "endpoint": "http://example.com",
    "endpointProperties": [
      {
        "@type": "EndpointProperty",
        "name": "authorization",
        "value": "TOKEN-ABCDEFG"
      },
      {
        "@type": "EndpointProperty",
        "name": "authType",
        "value": "bearer"
      }
    ]
  },
  "callbackAddress": "https://example.com/callback"
}

response = requests.request("POST", url, headers={
    "Content-Type": "application/json",
    "Authorization": "Bearer akuTZ784tLl7j96fX09XjK8ACYhdReuR4QHzfLClQP4"
}, data=json.dumps(payload))
response_as_text = response.text
response_as_text
# Out:
# ''

# %%
url = data_space_provider + "/dsp/current/transfers/request"
payload = {
  "@context": "https://w3id.org/dspace/2025/1/context.jsonld",
  "@graph": [
    {
      "@id": "_:msg",
      "@type": "TransferRequestMessage",
      "consumerPid": "urn:uuid:32541fe6-c580-409e-85a8-8a9a32fbe833",
      "agreementId": "urn:uuid:e8dc8655-44c2-46ef-b701-4cffdc2faa44",
      "format": "example:HTTP_PUSH",
      "callbackAddress": "https://example.com/callback",
      "dataAddress": { "@id": "_:addr" }
    },
    {
      "@id": "_:addr",
      "@type": "DataAddress",
      "endpointType": "https://w3id.org/idsa/v4.1/HTTP",
      "endpoint": "http://example.com",
      "endpointProperties": [{ "@id": "_:p1" }, { "@id": "_:p2" }]
    },
    { "@id": "_:p1", "@type": "EndpointProperty", "name": "authorization", "value": "TOKEN-ABCDEFG" },
    { "@id": "_:p2", "@type": "EndpointProperty", "name": "authType", "value": "bearer" }
  ]
}

response = requests.request("POST", url, headers={
    "Content-Type": "application/json",
    "Authorization": "Bearer akuTZ784tLl7j96fX09XjK8ACYhdReuR4QHzfLClQP4"
}, data=json.dumps(payload))
response_as_text = response.text
response_as_text
# Out:
# ''

# %%
url = data_space_provider + "/dsp/current/transfers/asd/start"
payload = [
  {
    "@type": ["https://w3id.org/dspace/2025/1/TransferRequestMessage"],
    "https://w3id.org/dspace/2025/1/consumerPid": [
      { "@id": "urn:uuid:32541fe6-c580-409e-85a8-8a9a32fbe833" }
    ],
    "https://w3id.org/dspace/2025/1/agreementId": [
      { "@id": "urn:uuid:e8dc8655-44c2-46ef-b701-4cffdc2faa44" }
    ],
    "http://purl.org/dc/terms/format": [
      { "@id": "example:HTTP_PUSH" }
    ],
    "https://w3id.org/dspace/2025/1/callbackAddress": [
      { "@value": "https://example.com/callback" }
    ],
    "https://w3id.org/dspace/2025/1/dataAddress": [
      {
        "@type": ["https://w3id.org/dspace/2025/1/DataAddress"],
        "https://w3id.org/dspace/2025/1/endpointType": [
          { "@id": "https://w3id.org/idsa/v4.1/HTTP" }
        ],
        "https://w3id.org/dspace/2025/1/endpoint": [
          { "@value": "http://example.com" }
        ],
        "https://w3id.org/dspace/2025/1/endpointProperties": [
          {
            "@type": ["https://w3id.org/dspace/2025/1/EndpointProperty"],
            "https://w3id.org/dspace/2025/1/name": [{ "@value": "authorization" }],
            "https://w3id.org/dspace/2025/1/value": [{ "@value": "TOKEN-ABCDEFG" }]
          },
          {
            "@type": ["https://w3id.org/dspace/2025/1/EndpointProperty"],
            "https://w3id.org/dspace/2025/1/name": [{ "@value": "authType" }],
            "https://w3id.org/dspace/2025/1/value": [{ "@value": "bearer" }]
          }
        ]
      }
    ]
  }
]

response = requests.request("POST", url, headers={
    "Content-Type": "application/json",
    "Authorization": "Bearer akuTZ784tLl7j96fX09XjK8ACYhdReuR4QHzfLClQP4"
}, data=json.dumps(payload))
response_as_text = response.text
response_as_text
# Out:
# ''
